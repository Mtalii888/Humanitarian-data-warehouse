# %%
import pandas

# %%
ref_data = pandas.read_csv(r"C:\Users\ELITEX21012G2\Desktop\REFUGEES PROJECT\refugees\refugees_raw.csv")
ref_df = pandas.DataFrame(ref_data)
ref_df.head()
# Out:
#    record_id  year country_of_origin country_of_asylum  refugees  \
# 0          1  2022            Uganda             Kenya     15880
# 1          2  2023          Ethiopia             Kenya     35103
# 2          3  2024            Uganda             Sudan     15151
# 3          4  2024           Burundi          Ethiopia     27184
# 4          5  2023            Rwanda          DR Congo     39382
#
#    asylum_seekers  idps
# 0            2109  6414
# 1             916  9947
# 2            2598  6158
# 3             678  8542
# 4            1432  3876

# %%
ref_df["country_of_origin"].unique()

# %%
ref_df["country_of_origin"] = ref_df["country_of_origin"].replace({"DRC":"DR Congo"})

# %%
ref_df["country_of_asylum"].unique()
# Out:
# <StringArray>
# [      'Kenya',       'Sudan',    'Ethiopia',    'DR Congo', 'South Sudan',
#       'Uganda',      'Rwanda',    'Tanzania',     'Burundi',     'Somalia']
# Length: 10, dtype: str

# %%
ref_df.isnull().sum()
# Out:
# record_id            0
# year                 0
# country_of_origin    0
# country_of_asylum    0
# refugees             0
# asylum_seekers       0
# idps                 0
# dtype: int64

# %%
ref_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
ref_df.to_csv(r"C:\Users\ELITEX21012G2\Desktop\REFUGEES PROJECT\refugees\refugees_cleaned.csv",index=False)
