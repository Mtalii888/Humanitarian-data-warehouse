# %%
import pandas

# %%
projects_data = pandas.read_csv(r"C:\Users\ELITEX21012G2\Desktop\REFUGEES PROJECT\data\raw\projects_raw.csv")
projects_df = pandas.DataFrame(projects_data)
projects_df
# Out:
#     project_id project_code            theme  donor_id  office_id
# 0            1     PRJ-0001       Protection       7.0          9
# 1            2     PRJ-0002           Health       6.0          3
# 2            3     PRJ-0003        Education       8.0          1
# 3            4     PRJ-0004       Protection       6.0         12
# 4            5     PRJ-0005    Food Security       5.0          8
# 5            6     PRJ-0006  Cash Assistance       NaN         10
# 6            7     PRJ-0007             WASH       2.0         12
# 7            8     PRJ-0008  Cash Assistance       7.0         12
# 8            9     PRJ-0009  Cash Assistance       1.0          5
# 9           10     PRJ-0010        Education       7.0          1
# 10          11     PRJ-0011  Cash Assistance       5.0          8
# 11          12     PRJ-0012  Cash Assistance       4.0         13
# 12          13     PRJ-0013        Education       4.0         11
# ...

# %%
projects_df.head()
# Out:
#    project_id project_code          theme  donor_id  office_id
# 0           1     PRJ-0001     Protection       7.0          9
# 1           2     PRJ-0002         Health       6.0          3
# 2           3     PRJ-0003      Education       8.0          1
# 3           4     PRJ-0004     Protection       6.0         12
# 4           5     PRJ-0005  Food Security       5.0          8

# %%
projects_df.isnull().sum()
# Out:
# project_id      0
# project_code    0
# theme           0
# donor_id        1
# office_id       0
# dtype: int64

# %%
projects_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
projects_df.describe().T
# Out:
#             count       mean       std  min   25%   50%    75%   max
# project_id   30.0  15.500000  8.803408  1.0  8.25  15.5  22.75  30.0
# donor_id     29.0   5.103448  2.127118  1.0  4.00   5.0   7.00   8.0
# office_id    30.0   7.166667  3.797307  1.0  3.25   8.0  10.75  13.0

# %%
projects_df = projects_df.dropna()

# %%
projects_df["theme"] = projects_df["theme"].str.title()

# %%
projects_df.to_csv(r"C:\Users\ELITEX21012G2\Desktop\REFUGEES PROJECT\data\clean\projects.csv",index=False)
