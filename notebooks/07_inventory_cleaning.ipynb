# %%
import pandas

# %%
inventory_data = pandas.read_csv(r"C:\Users\ELITEX21012G2\Desktop\REFUGEES PROJECT\refugees\inventory_raw.csv")

# %%
inventory_df = pandas.DataFrame(inventory_data)

# %%
inventory_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   inventory_id    1000 non-null   int64
#  1   warehouse_code  1000 non-null   str
#  2   item_name       999 non-null    str
#  3   stock_quantity  1000 non-null   int64
#  4   unit            1000 non-null   str
#  5   last_updated    1000 non-null   str
# dtypes: int64(2), str(4)
# memory usage: 47.0 KB

# %%
inventory_df.isnull().sum()

# %%
inventory_df =inventory_df.dropna()

# %%
inventory_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
inventory_df.head(20)
# Out:
#     inventory_id warehouse_code    item_name  stock_quantity unit last_updated
# 0              1         WH-001  Maize Flour            2814   kg   2026-05-13
# 1              2         WH-001      Lentils             687   kg   2025-10-26
# 2              3         WH-004  Cooking Oil            6241   kg   2025-12-17
# 3              4         WH-001        Sugar            4779   kg   2026-02-11
# 4              5         WH-002         Salt            2124   kg   2025-08-16
# 5              6         WH-004        Sugar             -10   kg   2026-01-29
# 6              7         WH-003      Lentils            6133   kg   2025-08-30
# 7              8         WH-002      Lentils            3779   kg   2025-09-18
# 8              9         WH-003      Lentils            4357   kg   2025-08-23
# 9             10        WH-001   Maize Flour            9432   kg   2026-05-29
# 10            11         WH-001  Cooking Oil            5109   kg   2026-03-30
# ...

# %%
inventory_df["last_updated"] = pandas.to_datetime(inventory_df["last_updated"])

# %%
inventory_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   inventory_id    999 non-null    int64
#  1   warehouse_code  999 non-null    str
#  2   item_name       999 non-null    str
#  3   stock_quantity  999 non-null    int64
#  4   unit            999 non-null    str
#  5   last_updated    999 non-null    datetime64[us]
# dtypes: datetime64[us](1), int64(2), str(3)
# memory usage: 54.6 KB

# %%
inventory_df["item_name"].unique()
# Out:
# <StringArray>
# ['Maize Flour', 'Lentils', 'Cooking Oil', 'Sugar', 'Salt', 'Beans', 'Rice']
# Length: 7, dtype: str

# %%
inventory_df.to_csv(r"C:\Users\ELITEX21012G2\Desktop\REFUGEES PROJECT\refugees\inventory_cleaned.csv",index=False)
