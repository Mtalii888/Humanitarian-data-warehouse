# %%
import pandas

# %%
donors_data = pandas.read_csv(r"C:\Users\ELITEX21012G2\Desktop\REFUGEES PROJECT\refugees\donors_raw.csv")

# %%
donors_df = pandas.DataFrame(donors_data)
donors_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   donor_id    8 non-null      int64
#  1   donor_name  7 non-null      str
#  2   donor_type  8 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 324.0 bytes

# %%
donors_df.isnull().sum()
# Out:
# donor_id      0
# donor_name    1
# donor_type    0
# dtype: int64

# %%
donors_df = donors_df.dropna()

# %%
donors_df
# Out:
#    donor_id donor_name  donor_type
# 0         1      USAID         NGO
# 1         2       ECHO         NGO
# 3         4      UNHCR  Government
# 4         5        WFP  Government
# 5         6       DFID   UN Agency
# 6         7      Norad         NGO
# 7         8        GIZ   UN Agency

# %%
donors_df.to_csv(r"C:\Users\ELITEX21012G2\Desktop\REFUGEES PROJECT\refugees\donors_cleaned.csv", index=False)
